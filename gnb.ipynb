# %%
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import numpy
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# y - values of images
# x - images

# %%
x_train = x_train.reshape(60000, 784) #one string of 784 characters
x_test = x_test.reshape(10000, 784)
#28x28px = 784

# %%
plt.imshow(x_train[1].reshape((28,28)) ,cmap = "gray") #28 arays of 28 characters

# %%
nb_model = GaussianNB() #creating the model
nb_model.fit(x_train, y_train) #training
# Out:
# GaussianNB()

# %%
predictions = nb_model.predict(x_test)

# %%
con_matrix = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=con_matrix)

# %%
disp.plot()

# %%
print(
    f"Classification report for classifier {nb_model}:\n"
    f"{classification_report(y_test, predictions)}\n"
)

#Preccison rzadko 1 uznane za 4
#Recall były 4 ale były uzane za inne
# Out:
# Classification report for classifier GaussianNB():
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       980
#            1       0.85      0.95      0.90      1135
#            2       0.90      0.26      0.40      1032
#            3       0.71      0.35      0.47      1010
#            4       0.88      0.17      0.29       982
#            5       0.55      0.05      0.09       892
#            6       0.65      0.93      0.77       958
#            7       0.88      0.27      0.42      1028
#            8       0.28      0.67      0.40       974
#            9       0.37      0.95      0.53      1009
#
#     accuracy                           0.56     10000
#    macro avg       0.69      0.55      0.51     10000
# weighted avg       0.69      0.56      0.52     10000
